# %% [markdown]
# # **Moniqo Group Project**
#
# ### **Data Cleaning**
#
# > -- Put any steps here

# %%
# Import necessary libraries

import pandas as pd
import numpy as np
from pathlib import Path

DATA_DIR = Path("data")  # adjust if needed

pd.set_option("display.max_columns", 100)

# %%
# Load datasets

# Customers
main_data = pd.read_csv(DATA_DIR / "repeat_loans_final.csv")

# %%
# Your code here
